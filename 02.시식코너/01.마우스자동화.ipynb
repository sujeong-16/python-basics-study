# %%
# 마우스와 키보드 제어를 도와주는 라이브러리
# 라이브러리 설치 방법은 pip install pyautogui
#   -> 설치할 때 주석을 같이 작성하면 오류나니 꼭 pip~ 만 작성하도록 하자.

# %%
pip install pyautogui

# %%
# 마우스 현재 위치 출력
import pyautogui
import time

time.sleep(2)
pyautogui.position()
# Out:
# Point(x=24, y=988)

# %%
# 현재 있는 좌표에서 moveTo(좌표)로 2초동안 이동
pyautogui.moveTo(24, 988, duration=2)

# %%
# 마우스 이동 후 클릭
pyautogui.moveTo(24, 988, duration=2)
pyautogui.click()
