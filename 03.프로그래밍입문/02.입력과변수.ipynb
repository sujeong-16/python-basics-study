# %%
champ_name = "티모"
champ_level = 10
champ_demage = 90
champ_skill = "버섯 깔기"

print(champ_name)
# Out:
# 티모

# %%
print(champ_level, champ_demage)
# Out:
# 10 90

# %%
print("챔피언 :", champ_name)
print("스킬 :", champ_skill)
# Out:
# 챔피언 : 티모
# 스킬 : 버섯 깔기

# %%
champ_level = 11
champ_demage = 95

# %%
print(champ_level, champ_demage)
# Out:
# 11 95
