# %%
print("start coding")
# Out:
# start coding

# %%
print('start coding')
# Out:
# start coding

# %%
# 오류 메세지: SyntaxError: incomplete input
print("Start coding"
# Out:
#   Cell In[3], line 1
#     print("Start coding"
#                         ^
# SyntaxError: incomplete input

# %%
# 오류 메세지: SyntaxError: unterminated string literal (detected at line 1)
print("start coding')
# Out:
#   Cell In[4], line 1
#     print("start coding')
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
# 코드 실행 순서
print("밥 먹었어?")
print("퇴근했어?")
# print("지금 뭐 해?")  단축키: Ctrl + /
# Out:
# 밥 먹었어?
# 퇴근했어?

# %%
# 여러 항목 출력
print("밥 먹었어?", "퇴근했어?")
# Out:
# 밥 먹었어? 퇴근했어?

# %%
# 문자열
"String"
'string'

# 정수(integer, int)
20
-5

# 실수(float)
3.14
-2.5

# 논리데이터 (Bool Boolean)
True
False
